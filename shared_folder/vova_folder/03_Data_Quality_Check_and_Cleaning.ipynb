# %% [markdown]
# <div style="
#   padding: 18px 24px;
#   margin-top: 15px;
#   margin-bottom: 25px;
#   border-left: 6px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   border-radius: 8px;
# ">
# <h1 style="margin:0; color:var(--jp-ui-font-color1);">
# 03. Data Quality Check & Cleaning
# </h1>
# <p style="font-size: 1.1em; color: var(--jp-ui-font-color1); margin-top: 6px;">
# Проверка качества данных и очистка
# </p>
# </div>

# %% [markdown]
# <h2 style="
#   padding: 6px 0;
#   border-bottom: 2px solid var(--jp-border-color2);
#   /* color: var(--jp-ui-font-color1); */
#   margin-top: 32px;
# ">
# 03.1 Проверка на дубли
# </h2>

# %%
from IPython.display import display
from utils import load_raw_df

df = load_raw_df()

# Ключ для поиска дублей - все колонки
key = df.columns.tolist()

# группы с количеством > 1
dup_groups = (
    df.groupby(key)
      .size()
      .reset_index(name='count')
      .query('count > 1')
)
print(f"Найдено дублирующихся групп: {len(dup_groups)}")
display(dup_groups)

# строки, которые считаются дублями (keep=False помечает все копии)
dups = df[df.duplicated(subset=key, keep=False)].sort_values(key)
print(f"Количество строк-дублей: {len(dups)}")
# Out:
# Найдено дублирующихся групп: 9
#       Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 5     Female  16.0    1.66    58.0                             no   no   2.0
# 73    Female  18.0    1.62    55.0                            yes  yes   2.0
# 369   Female  21.0    1.52    42.0                             no   no   3.0
# 370   Female  21.0    1.52    42.0                             no  yes   3.0
# 526   Female  22.0    1.69    65.0                            yes  yes   2.0
# 678   Female  25.0    1.57    55.0                             no  yes   2.0
# 1116    Male  18.0    1.72    53.0                            yes  yes   2.0
# 1343    Male  21.0    1.62    70.0                             no  yes   2.0
# 1459    Male  22.0    1.74    75.0                            yes  yes   3.0
#
#       NCP        CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 5     1.0   Sometimes    no   1.0  no  0.0  1.0         no
# 73    3.0  Frequently    no   1.0  no  1.0  1.0         no
# 369   1.0  Frequently    no   1.0  no  0.0  0.0  Sometimes
# 370   1.0  Frequently    no   1.0  no  0.0  0.0  Sometimes
# 526   3.0   Sometimes    no   2.0  no  1.0  1.0  Sometimes
# 678   1.0   Sometimes    no   2.0  no  2.0  0.0  Sometimes
# 1116  3.0   Sometimes    no   2.0  no  0.0  2.0  Sometimes
# 1343  1.0          no    no   3.0  no  1.0  0.0  Sometimes
# 1459  3.0  Frequently    no   1.0  no  1.0  0.0         no
#
#                      MTRANS           NObeyesdad  count
# 5                   Walking        Normal_Weight      2
# 73    Public_Transportation        Normal_Weight      2
# 369   Public_Transportation  Insufficient_Weight      2
# 370   Public_Transportation  Insufficient_Weight      4
# 526   Public_Transportation        Normal_Weight      2
# 678   Public_Transportation        Normal_Weight      2
# 1116  Public_Transportation  Insufficient_Weight      2
# 1343  Public_Transportation   Overweight_Level_I     15
# 1459             Automobile        Normal_Weight      2
# Количество строк-дублей: 33

# %% [markdown]
# <div style="
#   border-left: 4px solid var(--jp-warn-color0);
#   background: var(--jp-layout-color2);
#   padding: 12px 14px;
#   border-radius: 6px;
#   margin: 12px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>⚠️ Предупреждение:</strong><br>
# Есть дублирующиеся строки, уберем их чтобы они не приводили к дисбалансу
# </div>

# %%
df = df.drop_duplicates() # эта строка будет включена в load_clean_df()
